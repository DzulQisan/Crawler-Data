# %% [markdown]
# <a href="https://colab.research.google.com/github/DzulQisan/Crawler-Data/blob/master/CRAWLING_DATA_X.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***CRAWLING DATA X TERBARU KEYWORD : CHINDO***

# %%
# !pip install pandas
# !curl -sL https://deb.nodesource.com/setup_18.x | sudo -E bash -
# !sudo apt-get install -y nodejs
# Out:
# ...
# 2024-03-08 10:38:40 - Installing pre-requisites
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [736 kB]
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# ...

# %%
data = 'data_panas_bumi.csv'
search_keyword = 'panas until:2024-02-29 since:2024-01-01'
limit = 2000

# !npx --yes tweet-harvest@2.2.8 -o "{data}" -s "{search_keyword}" -l {limit} --token ""
# Out:
# Welcome to the Twitter Crawler 🕷️
#
# This script uses Chromium Browser to crawl data from Twitter with *your* Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
# ...

# %%
import pandas as pd

data = pd.read_csv("/content/tweets-data/data_panas_bumi.csv", sep=";")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445 entries, 0 to 444
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   created_at           445 non-null    object
#  1   id_str               445 non-null    int64
#  2   full_text            445 non-null    object
#  3   quote_count          445 non-null    int64
#  4   reply_count          445 non-null    int64
#  5   retweet_count        445 non-null    int64
#  6   favorite_count       445 non-null    int64
#  7   lang                 445 non-null    object
#  8   user_id_str          445 non-null    int64
#  9   conversation_id_str  445 non-null    int64
#  10  username             445 non-null    object
#  11  tweet_url            445 non-null    object
# dtypes: int64(7), object(5)
# memory usage: 41.8+ KB

# %%
data.head(112)
# Out:
#                          created_at               id_str  \
# 0    Wed Feb 28 23:59:50 +0000 2024  1762991028616003856
# 1    Wed Feb 28 23:59:31 +0000 2024  1762990949163298861
# 2    Wed Feb 28 23:59:00 +0000 2024  1762990819798339863
# 3    Wed Feb 28 23:58:50 +0000 2024  1762990774223044892
# 4    Wed Feb 28 23:58:30 +0000 2024  1762990692014739901
# ..                              ...                  ...
# 107  Wed Feb 28 23:21:14 +0000 2024  1762981314138153101
# 108  Wed Feb 28 23:20:50 +0000 2024  1762981212732137881
# 109  Wed Feb 28 23:20:48 +0000 2024  1762981203437564319
# 110  Wed Feb 28 23:20:44 +0000 2024  1762981187260465361
# 111  Wed Feb 28 23:20:30 +0000 2024  1762981130746446334
#
#                                              full_text  quote_count  \
# 0                                               Hisoka            0
# 1    Cara nurunin panas gimana sih woy ini udah 9 h...            0
# 2                             @urfavabegail panas gini            0
# ...
